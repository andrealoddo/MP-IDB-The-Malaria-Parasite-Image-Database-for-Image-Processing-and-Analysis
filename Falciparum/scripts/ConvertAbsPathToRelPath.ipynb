# %%
import pandas as pd
import os
from itertools import islice

df = pd.read_csv('mp-idb-falciparum-Copy1.csv')

for index, row in df.iterrows():
    df['filename'][index] = os.path.basename(os.path.normpath(df['filename'][index]))

df.head()
#df.to_csv('mp-idb-falciparum-Copy2.csv')
# Out:
# C:\Users\loand\Anaconda3\envs\scam_parser\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                   filename parasite_type  xmin  xmax  ymin  ymax
# 0  1305121398-0001-R_S.jpg          ring   919   887    76    67
# 1  1305121398-0001-R_S.jpg          schi  1246  1498   106   113
# 2  1305121398-0001-R_S.jpg          ring  1718   310    71    84
# 3    1305121398-0003-R.jpg          ring  1231   850    89    87
# 4    1305121398-0004-R.jpg          ring   815  1080    67    73

# %%
import csv

def updater(filename):
    with open(filename, newline= "") as file:
        readData = [row for row in csv.DictReader(file)]
        print(readData)
        readData[row]['filename'] = 'x'
        print(readData)

    readHeader = readData[0].keys()
    writer(readHeader, readData, filename, "update")

# %%
updater('mp-idb-falciparum-Copy1.csv')
# Out:
# [OrderedDict([('filename', 'C:\\Users\\loand\\Documents\\GitHub\\MP-IDB-The-Malaria-Parasite-Image-Database-for-Image-Processing-and-Analysis\\Falciparum\\img\\1305121398-0001-R_S.jpg'), ('parasite_type', 'ring'), ('xmin', '919'), ('xmax', '887'), ('ymin', '76'), ('ymax', '67')]), OrderedDict([('filename', 'C:\\Users\\loand\\Documents\\GitHub\\MP-IDB-The-Malaria-Parasite-Image-Database-for-Image-Processing-and-Analysis\\Falciparum\\img\\1305121398-0001-R_S.jpg'), ('parasite_type', 'schi'), ('xmin', '1246'), ('xmax', '1498'), ('ymin', '106'), ('ymax', '113')]), OrderedDict([('filename', 'C:\\Users\\loand\\Documents\\GitHub\\MP-IDB-The-Malaria-Parasite-Image-Database-for-Image-Processing-and-Analysis\\Falciparum\\img\\1305121398-0001-R_S.jpg'), ('parasite_type', 'ring'), ('xmin', '1718'), ('xmax', '310'), ('ymin', '71'), ('ymax', '84')]), OrderedDict([('filename', 'C:\\Users\\loand\\Documents\\GitHub\\MP-IDB-The-Malaria-Parasite-Image-Database-for-Image-Processing-and-Analysis\\Falcipa
# ...
